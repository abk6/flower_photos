# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %% [raw]
# Shubham Adsul - 220940128032
# Yash Patil - 220940128037
# Tejas Lidhure - 220940128013

# %% [markdown]
# # Deep Neural Networks
# ## Session 24b
#
# ##  Convolutional Neural Network (CNN)

# %% [markdown]
# This tutorial demonstrates training a simple [Convolutional Neural Network](https://developers.google.com/machine-learning/glossary/#convolutional_neural_network) (CNN) to classify Flowers dataset.

# %%
###-----------------
### Import Libraries
###-----------------

import os

import pandas as pd

import matplotlib.pyplot as plt

from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay


import tensorflow as tf

    
# %matplotlib inline

# %%
###------------------
### Memory Management
###------------------

physical_devices = tf.config.list_physical_devices('GPU') 

if len(physical_devices) > 0:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# 2022-12-16 17:53:39.034613: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 17:53:39.139808: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 17:53:39.140631: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
###---------------------------------------
### Global  parameters and Hyperparamaters
###---------------------------------------

inpDir = '/home/dai/ACTS_AI_Sept2022/Deep Neural Network/Input' # location where input data is stored
outDir = '/home/dai/ACTS_AI_Sept2022/Deep Neural Network/Output' # location to store outputs
subDir = '/kaggle/input/flower-photos/flower_photos' # location of the images
modelDir = '/kaggle/working/' # location to save model files
valDir = 'valid_flowers' # location related to this dataset
altName = 'dropout_bn_no_bias_leaky_flowers' # Model file name for this alternative
checkpoint_dir = '/kaggle/working/'

RANDOM_STATE = 24 # for initialization ----- REMEMBER: to remove at the time of promotion to production
tf.random.set_seed(RANDOM_STATE)


EPOCHS = 100   # number of cycles to run

ALPHA = 0.01

BATCH_SIZE = 16

TEST_SIZE = 0.2

IMG_HEIGHT = 190

IMG_WIDTH = 190

FLIP_MODE = "horizontal_and_vertical"

# for rotation transformation 
ROTATION_FACTOR = (-0.1, 0.1) 

FILL_MODE = 'nearest'

ES_PATIENCE = 20 # if performance does not improve stop

LR_PATIENCE = 10 # if performace is not improving reduce alpha

LR_FACTOR = 0.5 # rate of reduction of alpha


ES_PATIENCE = 10

LR_FACTOR = 0.9

LR_PATIENCE = 5


# Set parameters for decoration of plots
params = {'legend.fontsize' : 'large',
          'figure.figsize'  : (15,6),
          'axes.labelsize'  : 'x-large',
          'axes.titlesize'  :'x-large',
          'xtick.labelsize' :'large',
          'ytick.labelsize' :'large',
         }

CMAP = plt.cm.brg

plt.rcParams.update(params) # update rcParams

# %% [markdown]
# ## Helper Function

# %%
def fn_plot_hist(hist_df):
    
    '''
    Args:
        hist_df: a dataframe with following ccolumns
            column 0: loss
            column 1: accuracy
            column 2: val_loss
            column 3: val_accuracy
            While plotting columns are accessed by index 
            so that even if the column names are different it will not throw exceptions.
    '''
        
    # create figure and axis array
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)

    # take first axis
    ax = axes[0]

    # Plot Column 0 and 2 (Loss and validation loss)
    hist_df.plot(y = [hist_df.columns[0],hist_df.columns[2]], ax = ax, colormap=CMAP)

    # get minimum values for plotting
    lossmin = hist_df[hist_df.columns[0]].min()

    testmin = hist_df[hist_df.columns[2]].min()

    # little beautification
    txtstr = "Min {}: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(hist_df.columns[0],
                                                                          lossmin,
                                                                          testmin) #text to plot

    # place a text box in upper left in axes coords
    ax.text(0.4, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    # label the axes
    ax.set_xlabel("Epochs")

    ax.set_ylabel(hist_df.columns[0].capitalize())

    # grids make it look good
    ax.grid()
    
    # take second axis object
    ax = axes[1]

    # plot column 1 and 3 (accuracy and validation accuracy)
    hist_df.plot( y = [hist_df.columns[1], hist_df.columns[3]], ax = ax, colormap=CMAP)

    # little beautification
    accmin = hist_df[hist_df.columns[1]].max()
    testmin = hist_df[hist_df.columns[3]].max()
    txtstr = "Max {}: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(hist_df.columns[1],
                                                                                accmin,
                                                                                testmin) #text to plot

    # place a text box in upper left in axes coords
    ax.text(0.4, 0.5, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    # label the axes
    ax.set_xlabel("Epochs")
    
    ax.set_ylabel(hist_df.columns[1].capitalize())
    
    # grids make it look good
    ax.grid()
    
    # fit the subplot(s) in to the figure area
    plt.tight_layout()
    
    # display all open images
    plt.show()

# %%
# Function to plot number of classes in training and testing sets
def fn_plot_label(tr_ds, ts_ds):
    
    '''
        Args:
            tr_ds :  Training Dataset
            ts_ds : Testing dataset
        Returns : none
    '''

    # create figure
    plt.figure(figsize = (15,5))
    
    # create two subplots
    plt.subplot(1,2,1)

    # create array of training labels
    train_labels = tf.concat([y for x, y in tr_ds], axis = 0).numpy()
    
    # get unique labels and counts thereof
    unique, _, counts = tf.unique_with_counts(train_labels)
    
    # bar plot
    plt.bar(range(len(unique)), counts, align='center',color = 'DarkBlue', alpha = 0.7)
    
    # add title
    plt.title('Training Set')
    
    # add ticks on axis
    plt.xticks(range(len(unique)), class_names)
    
    # grids make it look good
    plt.grid()


    #pick second image
    plt.subplot(1,2,2)

    # create array of testing labels 
    val_labels = tf.concat([y for x, y in ts_ds], axis = 0).numpy()
    
    # get unique labels and counts thereof
    unique, _, counts = tf.unique_with_counts(val_labels)
    
    # bar plot
    plt.bar(range(len(unique)), counts, align='center', color = 'Orange', alpha = 0.7)
    
    # add title
    plt.title('Test Set')
    
    # add ticks
    plt.xticks(range(len(unique)), class_names)
    
    # grids make it look good
    plt.grid()
    
    # fit the subplot(s) in to the figure area
    plt.tight_layout()
    
    # display all open figures
    plt.show()

# %% [markdown]
# ## Load Dataset
#
# Images are under flower_photos
#
#      |- daisy
#      |- dandelion
#      |- roses
#      |- sunflowers
#      |- tulips

# %%
'''
    For reading from web link
'''

import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
data_dir = tf.keras.utils.get_file(origin=dataset_url,
                                   fname='flower_photos',
                                   untar=True)
data_dir = pathlib.Path(data_dir)
'''
    For reading from local directory
'''
#data_dir = os.path.join(inpDir, subDir)
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 6s 0us/step
# 228827136/228813984 [==============================] - 6s 0us/step
# '\n    For reading from local directory\n'

# %%
data_dir
# Out:
# PosixPath('/root/.keras/datasets/flower_photos')

# %%
# list content of data_dir
os.listdir(data_dir)
# Out:
# ['roses', 'dandelion', 'sunflowers', 'LICENSE.txt', 'daisy', 'tulips']

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=TEST_SIZE,
    subset='training',
    seed= RANDOM_STATE,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir,
    validation_split=TEST_SIZE,
    subset='validation',
    seed= RANDOM_STATE,
    image_size=(IMG_HEIGHT, IMG_WIDTH),
    batch_size=BATCH_SIZE)
# Out:
# Found 3670 files belonging to 5 classes.
# Using 2936 files for training.
# Found 3670 files belonging to 5 classes.
# Using 734 files for validation.
# 2022-12-16 17:53:48.747249: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-16 17:53:48.747649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 17:53:48.748492: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 17:53:48.749140: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 17:53:50.843459: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 17:53:50.844247: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 17:53:50.844950: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-16 17:53:50.845567: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# ### Is it picking the class names?

# %%
class_names = train_ds.class_names
print('total ', len(class_names), class_names)
# Out:
# total  5 ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']

# %% [markdown]
# ### Verify the data
#
# To verify that the dataset looks correct, let's plot the first batch from the training set and display the class name below each image.

# %%
# set figure size
plt.figure(figsize=(15,5))

# take one batch of the dataset
for images, labels in train_ds.take(1):
    
    # iterate through the batch
    for i in range(BATCH_SIZE):
        
        # add a subplot
        plt.subplot(int(BATCH_SIZE/8), 8, i+1 )
        
        # switch off the grids
        plt.grid(False)
        
        # image_size may have converted these images to float
        plt.imshow(images[i].numpy().astype("uint8")) 
        
        # display class in the title
        plt.title(class_names[labels[i]])
        
        # no axis
        plt.axis("off")
        
    # fit the subplot(s) in to the figure area
    plt.tight_layout()
    
# display all open images    
plt.show()
# Out:
# 2022-12-16 17:53:51.114567: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %%
# how many examples in each of the class
fn_plot_label(train_ds, test_ds)

# %%
# pick the input_shape 

input_shape = (IMG_HEIGHT, IMG_WIDTH, 3)

# %% [markdown]
# ## RandomZoom

# %%
layer = tf.keras.layers.RandomZoom(height_factor=(-0.2,-0.2),
                                   width_factor=(-0.2,-0.2)
                                  )

plt.figure()

img_num = 3

for images, labels in train_ds.take(1):
    
    out_images = layer(images)
    
    plt.subplot(1,2,1)
    
    plt.title('original')
    
    plt.imshow(images[img_num].numpy().astype('uint8'))
    
    plt.subplot(1,2,2)
    
    plt.title('zoomed')
    
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %% [markdown]
# ### Random Rotation

# %%
layer = tf.keras.layers.RandomRotation((-0.5, 0.5),
                                       fill_mode='nearest')

plt.figure()

img_num = 3

for images, labels in train_ds.take(1):
    
    out_images = layer(images)
    
    plt.subplot(1,2,1)
    
    plt.title('original')
    
    plt.imshow(images[img_num].numpy().astype('uint8'))
    
    plt.subplot(1,2,2)
    
    plt.title('rotated')
    
    plt.imshow(out_images[img_num].numpy().astype('uint8'))

# %% [markdown]
# ### Standardize the data
#
# The original RGB channel values are in the [0, 255] range. `Resizing` has converted those values into **floats**. Standardize values to be in the [0, 1] range by using the `tf.keras.layers.experimental.preprocessing.Rescaling` layer.

# %%
## Optimize for performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
model = tf.keras.Sequential()

# %%
model.add(tf.keras.layers.Rescaling(1./255.))

# %%
model.add(tf.keras.layers.RandomRotation(ROTATION_FACTOR, fill_mode= FILL_MODE, seed= RANDOM_STATE))
model.add(tf.keras.layers.RandomFlip(mode=FLIP_MODE, seed= RANDOM_STATE))

# %%
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(190, 190, 3))) #188X188
model.add(tf.keras.layers.MaxPooling2D((2, 2))) #94X94

model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu')) #92X92
model.add(tf.keras.layers.MaxPooling2D((2, 2)))  #46X46

model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu'))  #44X44
model.add(tf.keras.layers.MaxPooling2D((2, 2)))  #22X22

model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu')) #20X20
model.add(tf.keras.layers.MaxPooling2D((2, 2)))  #10X10

model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu'))  #8X8
model.add(tf.keras.layers.MaxPooling2D((2, 2)))  #4X4

model.add(tf.keras.layers.Conv2D(64, (3, 3), activation='relu')) #2*2


model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(512, activation='relu'))

model.add(tf.keras.layers.Dense(256, activation='relu'))

model.add(tf.keras.layers.Dense(128, activation='relu'))

model.add(tf.keras.layers.Dense(64, activation='relu'))

model.add(tf.keras.layers.Dense(5))

# %% [markdown]
# tf.keras.callbacks.EarlyStopping(
#     monitor='val_loss',
#     min_delta=0,
#     patience=0,
#     verbose=0,
#     mode='auto',
#     baseline=None,
#     restore_best_weights=False,
#     start_from_epoch=0
# )

# %%
#loss_fn = tf.keras.losses.sparse_categorical_crossentropy
#loss_fn = tf.keras.losses.CategoricalCrossentropy ( from_logits = True)

loss_fn = tf.keras.losses.SparseCategoricalCrossentropy( from_logits=True)

# %%
# Early Stopping
early_callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                                  restore_best_weights=True,
                                                  patience=ES_PATIENCE,
                                                  verbose=1)

checkpoint_filepath = os.path.join('/kaggle/working/abc/')

# Save weights
model_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath,
                                                    monitor='val_loss',
                                                    mode='auto',
                                                    save_weights_only=True,
                                                    save_best_only=True,
                                                    verbose=1)


# learning rate schedule
# Reduction schedule for alpha
lr_reduce = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                 factor=LR_FACTOR,
                                                 patience=LR_PATIENCE)

# %%
model.compile(optimizer='adam',
              loss=loss_fn,
              metrics=['accuracy']
         )

# %%
history = model.fit(train_ds, 
                    validation_data=test_ds,
                    batch_size=BATCH_SIZE,
                    epochs=100,
                   callbacks= [early_callback, model_callback, lr_reduce])
# Out:
# Epoch 1/100
# 2022-12-16 17:54:02.194277: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 184/184 [==============================] - 15s 38ms/step - loss: 1.4423 - accuracy: 0.3263 - val_loss: 1.3481 - val_accuracy: 0.3719
#
# Epoch 00001: val_loss improved from inf to 1.34811, saving model to /kaggle/working/abc/
# Epoch 2/100
# 184/184 [==============================] - 2s 12ms/step - loss: 1.2419 - accuracy: 0.4561 - val_loss: 1.2697 - val_accuracy: 0.4210
#
# Epoch 00002: val_loss improved from 1.34811 to 1.26971, saving model to /kaggle/working/abc/
# Epoch 3/100
# 184/184 [==============================] - 2s 13ms/step - loss: 1.1722 - accuracy: 0.4762 - val_loss: 1.2049 - val_accuracy: 0.4864
#
# Epoch 00003: val_loss improved from 1.26971 to 1.20488, saving model to /kaggle/working/abc/
# Epoch 4/100
# 184/184 [==============================] - 2s 12ms/step - loss: 1.0871 - accuracy: 0.5255 - val_loss: 1.2061 - val_accuracy: 0.4837
#
# Epoch 00004: val_loss did not improve from 1.20488
# Epoch 5/100
# 184/184 [==============================] - 2s 11ms/step - loss: 1.0506 - accuracy: 0.5429 - val_loss: 1.1018 - val_accuracy: 0.5027
#
# Epoch 00005: val_loss improved from 1.20488 to 1.10182, saving model to /kaggle/working/abc/
# Epoch 6/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.9776 - accuracy: 0.5913 - val_loss: 1.0212 - val_accuracy: 0.5708
#
# Epoch 00006: val_loss improved from 1.10182 to 1.02119, saving model to /kaggle/working/abc/
# Epoch 7/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.9562 - accuracy: 0.6093 - val_loss: 1.0432 - val_accuracy: 0.5586
#
# Epoch 00007: val_loss did not improve from 1.02119
# Epoch 8/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.9015 - accuracy: 0.6352 - val_loss: 0.9277 - val_accuracy: 0.6158
#
# Epoch 00008: val_loss improved from 1.02119 to 0.92766, saving model to /kaggle/working/abc/
# Epoch 9/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.9057 - accuracy: 0.6369 - val_loss: 0.9508 - val_accuracy: 0.6185
#
# Epoch 00009: val_loss did not improve from 0.92766
# Epoch 10/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.8472 - accuracy: 0.6649 - val_loss: 0.9492 - val_accuracy: 0.6267
#
# Epoch 00010: val_loss did not improve from 0.92766
# Epoch 11/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.8429 - accuracy: 0.6798 - val_loss: 1.0167 - val_accuracy: 0.5995
#
# Epoch 00011: val_loss did not improve from 0.92766
# Epoch 12/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.8212 - accuracy: 0.6747 - val_loss: 0.8945 - val_accuracy: 0.6281
#
# Epoch 00012: val_loss improved from 0.92766 to 0.89452, saving model to /kaggle/working/abc/
# Epoch 13/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.7991 - accuracy: 0.6979 - val_loss: 0.9467 - val_accuracy: 0.6090
#
# Epoch 00013: val_loss did not improve from 0.89452
# Epoch 14/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.8047 - accuracy: 0.6877 - val_loss: 0.8947 - val_accuracy: 0.6540
#
# Epoch 00014: val_loss did not improve from 0.89452
# Epoch 15/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.7768 - accuracy: 0.6948 - val_loss: 0.8544 - val_accuracy: 0.6689
#
# Epoch 00015: val_loss improved from 0.89452 to 0.85438, saving model to /kaggle/working/abc/
# Epoch 16/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.7492 - accuracy: 0.7105 - val_loss: 0.9084 - val_accuracy: 0.6390
#
# Epoch 00016: val_loss did not improve from 0.85438
# Epoch 17/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.7524 - accuracy: 0.7006 - val_loss: 0.8810 - val_accuracy: 0.6689
#
# Epoch 00017: val_loss did not improve from 0.85438
# Epoch 18/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.7421 - accuracy: 0.7129 - val_loss: 0.8045 - val_accuracy: 0.6948
#
# Epoch 00018: val_loss improved from 0.85438 to 0.80451, saving model to /kaggle/working/abc/
# Epoch 19/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.7261 - accuracy: 0.7173 - val_loss: 0.8430 - val_accuracy: 0.6771
#
# Epoch 00019: val_loss did not improve from 0.80451
# Epoch 20/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.7162 - accuracy: 0.7214 - val_loss: 0.7938 - val_accuracy: 0.6989
#
# Epoch 00020: val_loss improved from 0.80451 to 0.79382, saving model to /kaggle/working/abc/
# Epoch 21/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.7175 - accuracy: 0.7251 - val_loss: 0.8131 - val_accuracy: 0.6785
#
# Epoch 00021: val_loss did not improve from 0.79382
# Epoch 22/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6997 - accuracy: 0.7183 - val_loss: 0.8069 - val_accuracy: 0.6907
#
# Epoch 00022: val_loss did not improve from 0.79382
# Epoch 23/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6925 - accuracy: 0.7200 - val_loss: 0.7544 - val_accuracy: 0.7193
#
# Epoch 00023: val_loss improved from 0.79382 to 0.75439, saving model to /kaggle/working/abc/
# Epoch 24/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.6661 - accuracy: 0.7326 - val_loss: 0.7659 - val_accuracy: 0.7016
#
# Epoch 00024: val_loss did not improve from 0.75439
# Epoch 25/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.6600 - accuracy: 0.7425 - val_loss: 0.7978 - val_accuracy: 0.6866
#
# Epoch 00025: val_loss did not improve from 0.75439
# Epoch 26/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6697 - accuracy: 0.7388 - val_loss: 0.8245 - val_accuracy: 0.6975
#
# Epoch 00026: val_loss did not improve from 0.75439
# Epoch 27/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6421 - accuracy: 0.7469 - val_loss: 0.7580 - val_accuracy: 0.7030
#
# Epoch 00027: val_loss did not improve from 0.75439
# Epoch 28/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6435 - accuracy: 0.7490 - val_loss: 0.7777 - val_accuracy: 0.7153
#
# Epoch 00028: val_loss did not improve from 0.75439
# Epoch 29/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.6342 - accuracy: 0.7456 - val_loss: 0.7186 - val_accuracy: 0.7193
#
# Epoch 00029: val_loss improved from 0.75439 to 0.71861, saving model to /kaggle/working/abc/
# Epoch 30/100
# 184/184 [==============================] - 2s 13ms/step - loss: 0.5873 - accuracy: 0.7681 - val_loss: 0.7511 - val_accuracy: 0.7262
#
# Epoch 00030: val_loss did not improve from 0.71861
# Epoch 31/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.6081 - accuracy: 0.7626 - val_loss: 0.7825 - val_accuracy: 0.7207
#
# Epoch 00031: val_loss did not improve from 0.71861
# Epoch 32/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5729 - accuracy: 0.7715 - val_loss: 0.7490 - val_accuracy: 0.7193
#
# Epoch 00032: val_loss did not improve from 0.71861
# Epoch 33/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.5870 - accuracy: 0.7708 - val_loss: 0.7367 - val_accuracy: 0.7139
#
# Epoch 00033: val_loss did not improve from 0.71861
# Epoch 34/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5843 - accuracy: 0.7749 - val_loss: 0.7078 - val_accuracy: 0.7302
#
# Epoch 00034: val_loss improved from 0.71861 to 0.70779, saving model to /kaggle/working/abc/
# Epoch 35/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5773 - accuracy: 0.7691 - val_loss: 0.7815 - val_accuracy: 0.7180
#
# Epoch 00035: val_loss did not improve from 0.70779
# Epoch 36/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.5499 - accuracy: 0.7854 - val_loss: 0.7931 - val_accuracy: 0.7016
#
# Epoch 00036: val_loss did not improve from 0.70779
# Epoch 37/100
# 184/184 [==============================] - 2s 11ms/step - loss: 0.5622 - accuracy: 0.7861 - val_loss: 0.7377 - val_accuracy: 0.7398
#
# Epoch 00037: val_loss did not improve from 0.70779
# Epoch 38/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5616 - accuracy: 0.7817 - val_loss: 0.7609 - val_accuracy: 0.7153
#
# Epoch 00038: val_loss did not improve from 0.70779
# Epoch 39/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5493 - accuracy: 0.7721 - val_loss: 0.7971 - val_accuracy: 0.7057
#
# Epoch 00039: val_loss did not improve from 0.70779
# Epoch 40/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5171 - accuracy: 0.8025 - val_loss: 0.7927 - val_accuracy: 0.7384
#
# Epoch 00040: val_loss did not improve from 0.70779
# Epoch 41/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5184 - accuracy: 0.7909 - val_loss: 0.7788 - val_accuracy: 0.7411
#
# Epoch 00041: val_loss did not improve from 0.70779
# Epoch 42/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5315 - accuracy: 0.7946 - val_loss: 0.7099 - val_accuracy: 0.7357
#
# Epoch 00042: val_loss did not improve from 0.70779
# Epoch 43/100
# 184/184 [==============================] - 3s 14ms/step - loss: 0.5114 - accuracy: 0.7963 - val_loss: 0.7541 - val_accuracy: 0.7302
#
# Epoch 00043: val_loss did not improve from 0.70779
# Epoch 44/100
# 184/184 [==============================] - 2s 12ms/step - loss: 0.5024 - accuracy: 0.8065 - val_loss: 0.7294 - val_accuracy: 0.7411
# Restoring model weights from the end of the best epoch.
#
# Epoch 00044: val_loss did not improve from 0.70779
# Epoch 00044: early stopping

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 190, 190, 3)       0
# _________________________________________________________________
# random_rotation_1 (RandomRot (None, 190, 190, 3)       0
# _________________________________________________________________
# random_flip (RandomFlip)     (None, 190, 190, 3)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 188, 188, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 94, 94, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 92, 92, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 46, 46, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 44, 44, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 20, 20, 32)        9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 10, 10, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 2, 2, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               131584
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 388,453
# Trainable params: 388,453
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.evaluate ( test_ds, verbose=2)
# Out:
# 46/46 - 0s - loss: 0.7078 - accuracy: 0.7302
# [0.7077884674072266, 0.7302452325820923]

# %%
def fn_plot_hist(hist_df):
    
    fig, axes = plt.subplots(1,2 , figsize = (15,6))

    # properties  matplotlib.patch.Patch 
    props = dict(boxstyle='round', facecolor='aqua', alpha=0.4)

    ax = axes[0]

    hist_df.plot(y = ['loss','val_loss'], ax = ax, colormap=CMAP)

    lossmin = hist_df['loss'].min()

    testmin = hist_df['val_loss'].min()

    # little beautification
    txtstr = "Min Loss: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(lossmin,
                                                                            testmin) #text to plot

    # place a text box in upper left in axes coords

    ax.text(0.4, 0.95, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    ax.set_xlabel("Epochs")

    ax.set_ylabel("Loss")

    ax.grid();

    ax = axes[1]

    hist_df.plot( y = ['accuracy', 'val_accuracy'], ax = ax, colormap=CMAP)
    acc = hist_df['accuracy'].values
    # little beautification
    accmax = hist_df['accuracy'].max()
    testmax = hist_df['val_accuracy'].max()
    txtstr = "Max Accuracy: \n Training : {:7.4f}\n Testing   : {:7.4f}".format(accmax,
                                                                                testmax) #text to plot

    # place a text box in upper left in axes coords

    ax.text(0.4, 0.5, txtstr, transform=ax.transAxes, fontsize=14,
            verticalalignment='top', bbox=props)

    ax.set_xlabel("Epochs")
    ax.set_ylabel("Accuracy")
    ax.grid();
    plt.tight_layout()

# %%
hist_df = pd.DataFrame(history.history)
hist_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy     lr
# 0  1.442263  0.326294  1.348105      0.371935  0.001
# 1  1.241893  0.456063  1.269710      0.420981  0.001
# 2  1.172200  0.476158  1.204879      0.486376  0.001
# 3  1.087079  0.525545  1.206117      0.483651  0.001
# 4  1.050618  0.542916  1.101818      0.502725  0.001

# %%
fn_plot_hist(hist_df)

# %% [markdown]
# ### Reload best Weights for evaluation

# %%
del model

# %%
tf.train.latest_checkpoint(checkpoint_dir)

# %%
num_classes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_23/3539077230.py in <module>
# ----> 1 num_classes
#
# NameError: name 'num_classes' is not defined

# %%
model1 = build_model(input_shape, num_classes)

model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))

model.compile(optimizer=tf.keras.optimizers.Adam(),
              loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Evaluate the model

# %%
#yhat = model.predict(X_test, batch_size=n_batch)
yhat = model.predict(test_ds)

# %%
y_test = tf.concat([y for x, y in test_ds], axis=0)

# %%
y_pred = yhat.argmax(axis = 1)

print('Accuracy score on Test Data : {:.3f}%'.format( accuracy_score(y_test, y_pred)*100))

# %%
cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                       display_labels=class_names)

fig, ax = plt.subplots(figsize = (9,9))

disp.plot(ax = ax, cmap=plt.cm.Blues, colorbar=False);

ax.set_xticklabels(class_names,rotation=45, ha='right');

# %%
for images, labels in test_ds.take( 5 ):
    
    # Predict again to keep y_pred in synch with the images
    yhat = model.predict(images, verbose = 0)
    
    y_pred = yhat.argmax(axis = 1)
    
    for i in range ( BATCH_SIZE ):
        
        plt.subplot(int( BATCH_SIZE / 8 ), 8, i+1 )
        
        plt.grid(False)
        
        plt.imshow ( images[i].numpy().astype( "uint8" ) )
        
        plt.title('{} \n {}'.format( class_names[labels.numpy()[i]], class_names[y_pred[i]]))
        
        plt.axis("off")
        
    plt.tight_layout()
    
    plt.show()

# %%
test_loss, test_acc = model.evaluate(test_ds, verbose=1)

# %% [markdown]
# ### Save complete model for future use

# %%
model_path = checkpoint_prefix+'.h5'
model.save(model_path, save_format='h5')

# %% [markdown]
# ### Verify if everything was saved ok

# %%
new_model = tf.keras.models.load_model(model_path)

# %%
new_model.summary()

# %%
yhat = new_model.predict(test_ds)

y_pred = yhat.argmax(axis = 1)

print('Accuracy score on Test Data : {:.3f}%'.format( accuracy_score(y_test, y_pred)*100))
